# %% [markdown]
# # TP n°4 : Arbres de Classification

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc
from sklearn.metrics import accuracy_score

# %%
from tptreesource import *

# %% [markdown]
# ## Question 1)
# Dans le cadre de la régression (i.e., quand on cherche à prédire une valeur numérique pour Y et
# non une classe), proposez une autre mesure d’homogénéité. Justifier votre choix.

# %% [markdown]
# **Réponse** : Une autre mesure pour le cas de la régression peut correspondre à une mesure de pénalisation L2 entre la vraie valeur y et la valeur prédite. On souhaiterait alors minimiser l'écart au carré entre nos prédictions et les vraies valeurs. (Variance)

# %% [markdown]
# ## Question 2)
# Simulez avec rand_checkers des échantillons de taille n = 456 (attention à bien équilibrer les
# classes). Créez deux courbes qui donnent le pourcentage d’erreurs commises en fonction de la
# profondeur maximale de l’arbre (une courbe pour Gini, une courbe pour l’entropie). On laissera les
# autres paramètres à leur valeurs par défaut.

# %%
from sklearn import tree

# %%
n1 = 456 // 4
n2 = 456 // 4
n3 = 456 // 4
n4 = 456 // 4
sigma = 0.1

res = rand_checkers(n1, n2, n3, n4, sigma)
print(res.shape)
# Out:
# (448, 3)

# %%
X = res[:,:2]
y = res[:,-1]

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.3, random_state = 100)

# %%
i = 0
err1 = []
err2 = []

#Range à tester pour la profondeur
for max_depth in range(1,50) :
    
    #On teste les deux modèles : Gini et Entropy
    df1 = tree.DecisionTreeClassifier(criterion = "gini", max_depth = max_depth)
    df2 = tree.DecisionTreeClassifier(criterion = "entropy", max_depth = max_depth)
    
    df1.fit(X_train, y_train)
    pred1 = df1.predict(X_test)
    
    df2.fit(X_train, y_train)
    pred2 = df2.predict(X_test)
    
    #Erreurs
    err1.append(100-accuracy_score(y_test,pred1)*100)
    err2.append(100-accuracy_score(y_test,pred2)*100)
    
    i = i + 1

# %%
#Plot les erreurs
plt.figure(1,figsize=(18,7))

plt.subplot(121)
plt.title("Gini")
plt.plot(err1)

plt.subplot(122)
plt.title("Entropy")
plt.plot(err2)

plt.show()

# %% [markdown]
# ## Question 3)
# Afficher la règle de classification obtenue en utilisant la profondeur qui minimise le pourcentage
# d’erreurs obtenues avec l’entropie et avec l’indice de Gini (utiliser si besoin les fonctions plot_2d
# et frontiere du fichier source).

# %%
#Récupérer l'index qui minimise l'erreur
indx1 = err1.index(min(err1))
indx2 = err2.index(min(err2))

# %%
#Decision Tree Classifier avec la meilleur profondeur
df1 = tree.DecisionTreeClassifier(criterion = "gini", max_depth = indx1)
df2 = tree.DecisionTreeClassifier(criterion = "entropy", max_depth = indx2)

df1.fit(X_train, y_train)
pred1 = df1.predict(X_test)
    
df2.fit(X_train, y_train)
pred2 = df2.predict(X_test)

# %%
#Tracer la frontière
df1 = tree.DecisionTreeClassifier(criterion = "gini", max_depth = indx2).fit(X_train, y_train)
df2 = tree.DecisionTreeClassifier(criterion = "entropy", max_depth = indx2).fit(X_train, y_train)

def pred_new1(X) :
    return df1.predict(X.reshape(1,-1))

def pred_new2(X) :
    return df2.predict(X.reshape(1,-1))

plt.figure(1,figsize=(14,7))

plt.subplot(121)
plt.title("Gini")
frontiere_new(pred_new1, X_test, y_test)

plt.subplot(122)
plt.title("Entropy")
frontiere_new(pred_new2, X_test, y_test)

plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ## Question 4)
# Exporter des graphiques des arbres obtenu à la question précédente en format pdf. On pourra par
# exemple utiliser la fonction export_graphviz du module tree.

# %%
#Exporter le graph
tree.export_graphviz(df1, out_file='tree.dot')

# %%
from subprocess import check_call
check_call(['dot','-Tpng','tree.dot','-o','OutputFile.png'])
# Out:
# 0

# %% [markdown]
# <img src="OutputFile.png">

# %% [markdown]
# ## Question 5)
# Créez n = 160 = 40 + 40 + 40 + 40 nouvelles données avec rand_checkers. Pour les arbres de
# décision entraînés précédemment (dans partie (2)), calculer la proportion d’erreurs faites sur cet
# échantillon de test. Commenter.

# %%
#Créer un nouvel échantillon test
n1 = 40
n2 = 40
n3 = 40
n4 = 40
sigma = 0.1

res = rand_checkers(n1, n2, n3, n4, sigma)

# %%
#Définir X_new et y_new
X_new = res[:,:2]
y_new = res[:,-1]

# %%
#Calculer la nouvelle erreur associée à ces nouveaux échantillons
i = 0
err1 = []
err2 = []

for max_depth in range(1,50) :
    
    df1 = tree.DecisionTreeClassifier(criterion = "gini", max_depth = max_depth)
    df2 = tree.DecisionTreeClassifier(criterion = "entropy", max_depth = max_depth)
    
    df1.fit(X_train, y_train)
    pred1 = df1.predict(X_new)
    
    df2.fit(X_train, y_train)
    pred2 = df2.predict(X_new)
    
    err1.append(100-accuracy_score(y_new,pred1)*100)
    err2.append(100-accuracy_score(y_new,pred2)*100)
    
    i = i + 1

# %%
plt.figure(1,figsize=(14,7))

plt.subplot(121)
plt.title("Gini")
plt.plot(err1)

plt.subplot(122)
plt.title("Entropy")
plt.plot(err2)

plt.show()

# %%
indx1 = err1.index(min(err1))
indx2 = err2.index(min(err2))
print("Profondeur optimale associée au modèle Gini : " + str(indx1) + "\n" + "Profondeur optimale associée au modèle Entropy : "+ str(indx2))
# Out:
# Profondeur optimale associée au modèle Gini : 17
# Profondeur optimale associée au modèle Entropy : 14

# %% [markdown]
# Les profondeurs optimales ont changé, et il faut généralement s'arrêter plus tôt sur un nouvel échantillon pour éviter l'overfitting.

# %% [markdown]
# ## Question 6)
# Reprendre les questions précédentes pour le dataset zipcode. Ce jeu de données est disponible dans
# le module sklearn.datasets. On peut l’importer avec la fonction load_digits du dit module (ou
# voir pour plus de détails http://scikit-learn.org/stable/auto_examples/classification/plot_digits_classification.html) :

# %%
from sklearn import datasets
digits = datasets.load_digits()

# %%
X = digits.data
y = digits.target
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state = 100)

# %%
i = 0
err1 = []
err2 = []

for max_depth in range(1,50) :
    
    df1 = tree.DecisionTreeClassifier(criterion = "gini", max_depth = max_depth)
    df2 = tree.DecisionTreeClassifier(criterion = "entropy", max_depth = max_depth)
    
    df1.fit(X_train, y_train)
    pred1 = df1.predict(X_test)
    
    df2.fit(X_train, y_train)
    pred2 = df2.predict(X_test)
    
    err1.append(100-accuracy_score(y_test,pred1)*100)
    err2.append(100-accuracy_score(y_test,pred2)*100)
    
    i = i + 1

# %%
plt.figure(1,figsize=(14,7))

plt.subplot(121)
plt.title("Gini")
plt.plot(err1)

plt.subplot(122)
plt.title("Entropy")
plt.plot(err2)

plt.show()

# %%
indx1 = err1.index(min(err1))
indx2 = err2.index(min(err2))
print("Profondeur optimale associée au modèle Gini : " + str(indx1) + "\n" + "Profondeur optimale associée au modèle Entropy : "+ str(indx2))
# Out:
# Profondeur optimale associée au modèle Gini : 8
# Profondeur optimale associée au modèle Entropy : 38

# %%
#Si on change les nouvelles données test :
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state = 99)

# %%
i = 0
err1 = []
err2 = []

for max_depth in range(1,50) :
    
    df1 = tree.DecisionTreeClassifier(criterion = "gini", max_depth = max_depth)
    df2 = tree.DecisionTreeClassifier(criterion = "entropy", max_depth = max_depth)
    
    df1.fit(X_train, y_train)
    pred1 = df1.predict(X_test)
    
    df2.fit(X_train, y_train)
    pred2 = df2.predict(X_test)
    
    err1.append(100-accuracy_score(y_test,pred1)*100)
    err2.append(100-accuracy_score(y_test,pred2)*100)
    
    i = i + 1

# %%
plt.figure(1,figsize=(14,7))

plt.subplot(121)
plt.title("Gini")
plt.plot(err1)

plt.subplot(122)
plt.title("Entropy")
plt.plot(err2)

plt.show()

# %%
indx1 = err1.index(min(err1))
indx2 = err2.index(min(err2))
print("Profondeur optimale associée au modèle Gini : " + str(indx1) + "\n" + "Profondeur optimale associée au modèle Entropy : "+ str(indx2))
# Out:
# Profondeur optimale associée au modèle Gini : 33
# Profondeur optimale associée au modèle Entropy : 26

# %% [markdown]
# Encore une fois, les profondeurs optimales ont changé, et il faut généralement s'arrêter plus tôt sur un nouvel échantillon pour éviter l'overfitting.

# %% [markdown]
# ## Question 7
# Utiliser la fonction sklearn.model_selection.cross_val_score et tester la sur le jeu de données
# zipcode en faisant varier la profondeur de l’arbre de décision. On pourra se servir de cette fonction
# pour choisir la profondeur de l’arbre

# %%
from sklearn.model_selection import cross_val_score
df1 = tree.DecisionTreeClassifier(criterion = "gini")
df2 = tree.DecisionTreeClassifier(criterion = "entropy")
print(cross_val_score(df1, X, y, cv=5))
print(cross_val_score(df2, X, y, cv=5))
# Out:
# [0.78296703 0.71270718 0.79108635 0.83753501 0.78591549]
# [0.81868132 0.77624309 0.81615599 0.82352941 0.78028169]

# %%
depth1 = []
depth2 = []

for i in range(1,50):
    clf1 = tree.DecisionTreeClassifier(criterion = "gini", max_depth=i)
    clf2 = tree.DecisionTreeClassifier(criterion = "entropy", max_depth=i)
    # Perform 5-fold cross validation 
    scores1 = cross_val_score(estimator=clf1, X=X, y=y, cv=5)
    scores2 = cross_val_score(estimator=clf2, X=X, y=y, cv=5)
    depth1.append(scores1.mean())
    depth2.append(scores2.mean())

# %%
print(depth1.index(max(depth1)), max(depth1))
print(depth2.index(max(depth2)), max(depth2))
clf2 = tree.DecisionTreeClassifier(criterion = "gini", max_depth=depth1.index(max(depth1)))
clf1 = tree.DecisionTreeClassifier(criterion = "entropy", max_depth=depth2.index(max(depth2)))
# Out:
# 18 0.7937374200773298
# 14 0.8169564302812473

# %% [markdown]
# ## Question 8)
# En s’inspirant de http://scikit-learn.org/stable/auto_examples/model_selection/plot_
# learning_curve.html afficher la courbe d’apprentissage (en : learning curve) pour les arbres de
# décisions sur le même jeu de données 2

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5)):
    """Generate a simple plot of the test and training learning curve"""
    from sklearn.model_selection import learning_curve
    plt.figure(figsize=(12,6))
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()
    
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
g = plot_learning_curve(clf1,"Decision Tree : Gini",X,y,cv=5)

# %%
g = plot_learning_curve(clf2,"Decision Tree : Entropy",X,y,cv=5)
